# %% [markdown]
# # Train sarcasm classifiers (standard / topic_hard)
#
# Saves weights under `artifacts/classifiers/<logreg|rnn|transformer>/<split>/`, matching `test_systems.ipynb` and `batch_style_probs`.
#
# Prefer the CLI for long runs: `py -3 classifiers/train_classifiers.py --split standard --models all`.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path("..").resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

SPLIT_NAME = "standard"  # or "topic_hard"

from data.splits import SPLIT_REGISTRY
assert SPLIT_NAME in SPLIT_REGISTRY, f"Use one of {sorted(SPLIT_REGISTRY)}"
print(f"Project root: {PROJECT_ROOT}")
print(f"Training split: {SPLIT_NAME}")

# %% [markdown]
# ## LogReg (TF–IDF + logistic regression)
#
# Fast CPU training.

# %%
from classifiers.logreg_classifier import train as train_logreg

train_logreg(split=SPLIT_NAME)

# %% [markdown]
# ## RNN (BiLSTM)
#
# Uses PyTorch; GPU recommended.

# %%
from classifiers.rnn_classifier import train as train_rnn

train_rnn(split=SPLIT_NAME)

# %% [markdown]
# ## Transformer (DistilBERT)
#
# Heaviest step; needs `transformers` + GPU for reasonable runtime.

# %%
from classifiers.transformer_classifier import train as train_transformer

train_transformer(split=SPLIT_NAME)
